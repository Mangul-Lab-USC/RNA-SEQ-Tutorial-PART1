# %% [markdown]
# Set up Anaconda and Bioconda in Google Colab notebook.

# %%
# !wget https://repo.anaconda.com/archive/Anaconda3-2019.10-Linux-x86_64.sh && bash Anaconda3-2019.10-Linux-x86_64.sh -bfp /usr/local
# Out:
# --2020-05-16 00:57:52--  https://repo.anaconda.com/archive/Anaconda3-2019.10-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 530308481 (506M) [application/x-sh]
# Saving to: ‘Anaconda3-2019.10-Linux-x86_64.sh’
#
# Anaconda3-2019.10-L 100%[===================>] 505.74M   128MB/s    in 3.9s
#
# 2020-05-16 00:57:56 (128 MB/s) - ‘Anaconda3-2019.10-Linux-x86_64.sh’ saved [530308481/530308481]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _ipyw_jlab_nb_ext_conf==0.1.0=py37_0
#     - _libgcc_mutex==0.1=main
#     - alabaster==0.7.12=py37_0
#     - anaconda-client==1.7.2=py37_0
#     - anaconda-navigator==1.9.7=py37_0
#     - anaconda-project==0.8.3=py_0
# ...

# %% [markdown]
# Attach packages to python environment

# %%
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages')

# %% [markdown]
# Set Up and Activate Bioconda Channels

# %%
# !conda config --add channels defaults
# !conda config --add channels bioconda
# !conda config --add channels conda-forge

# %% [markdown]
# With an activated Bioconda Channel, Install Bioconductor.

# %%
# !conda install bioconductor-all
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - bioconductor-all
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _r-mutex-1.0.1             |      anacondar_1           3 KB  conda-forge
#     binutils_impl_linux-64-2.31.1|       h6176602_1         3.9 MB
#     binutils_linux-64-2.31.1   |       h6176602_9          26 KB
#     bioconductor-all-1.22.0    |           r351_0           5 KB  bioconda
#     bioconductor-biobase-2.40.0|   r351ha44fe06_1         2.3 MB  bioconda
#     bioconductor-biocgenerics-0.26.0|           r351_0         692 KB  bioconda
# ...

# %% [markdown]
# Install hisat2, samtools htseq, salmon, deseq2 with conda

# %%
# !conda install hisat2
# conda install -c bioconda hisat2
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - hisat2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     hisat2-2.2.0               |   py37h3340039_2        13.2 MB  bioconda
#     perl-5.26.2                |    h516909a_1006        15.4 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        28.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   hisat2             bioconda/linux-64::hisat2-2.2.0-py37h3340039_2
#   perl               conda-forge/linux-64::perl-5.26.2-h516909a_1006
#
#
# Proceed ([y]/n)? y
#
#
# ...
# hisat2-2.2.0         | 13.2 MB   | : 100% 1.0/1 [00:04<00:00,  4.06s/it]
# perl-5.26.2          | 15.4 MB   | : 100% 1.0/1 [00:03<00:00,  2.43s/it]
# done
# done
# done

# %%
# !conda install samtools
# conda install -c bioconda samtools
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - samtools
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     htslib-1.9                 |       ha228f0b_7         1.5 MB  bioconda
#     samtools-1.9               |      h10a08f8_12         299 KB  bioconda
#     ------------------------------------------------------------
#                                            Total:         1.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   htslib             bioconda/linux-64::htslib-1.9-ha228f0b_7
#   samtools           bioconda/linux-64::samtools-1.9-h10a08f8_12
#
#
# Proceed ([y]/n)? y
#
#
# ...
# htslib-1.9           | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  3.20it/s]
# samtools-1.9         | 299 KB    | : 100% 1.0/1 [00:00<00:00,  2.81it/s]
# done
# done
# done

# %%
# !conda install htseq
# conda install -c bioconda htseq
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - htseq
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     htseq-0.12.4               |   py37hb3f55d8_0         338 KB  bioconda
#     libdeflate-1.0             |       h14c3975_1          43 KB  bioconda
#     matplotlib-base-3.1.3      |   py37hef1b27d_0         5.0 MB
#     pysam-0.15.3               |   py37hda2845c_1         2.5 MB  bioconda
#     ------------------------------------------------------------
#                                            Total:         7.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   htseq              bioconda/linux-64::htseq-0.12.4-py37hb3f55d8_0
#   libdeflate         bioconda/linux-64::libdeflate-1.0-h14c3975_1
#   matplotlib-base    pkgs/main/linux-64::matplotlib-base-3.1.3-py37hef1b27d_0
# ...

# %%
# !conda install salmon
# conda install -c bioconda salmon
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - salmon
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     jemalloc-5.2.1             |       he1b5a44_1        11.8 MB  conda-forge
#     libboost-1.71.0            |       h97c9712_0        15.2 MB
#     salmon-0.13.1              |       h86b0361_0         4.2 MB  bioconda
#     ------------------------------------------------------------
#                                            Total:        31.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   jemalloc           conda-forge/linux-64::jemalloc-5.2.1-he1b5a44_1
#   libboost           pkgs/main/linux-64::libboost-1.71.0-h97c9712_0
#   salmon             bioconda/linux-64::salmon-0.13.1-h86b0361_0
#
#
# Proceed ([y]/n)? y
#
#
# ...
# jemalloc-5.2.1       | 11.8 MB   | : 100% 1.0/1 [00:01<00:00,  1.09it/s]
# ...

# %%
# !conda install bioconductor-deseq2
# conda install -c bioconda bioconductor-deseq2
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - bioconductor-deseq2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bioconductor-annotate-1.58.0|           r351_0         2.1 MB  bioconda
#     bioconductor-annotationdbi-1.42.1|           r351_0         4.9 MB  bioconda
#     bioconductor-biocparallel-1.14.2|   r351h26a2512_0         1.1 MB  bioconda
#     bioconductor-delayedarray-0.6.6|           r351_0         1.4 MB  bioconda
#     bioconductor-deseq2-1.20.0 |   r351hfc679d8_0         2.6 MB  bioconda
#     bioconductor-genefilter-1.62.0|   r351h26a2512_0         1.7 MB  bioconda
# ...

# %% [markdown]
# List available packages

# %%
# !conda info --all
# !conda list
# Out:
#      active environment : None
#        user config file : /root/.condarc
#  populated config files : /root/.condarc
#           conda version : 4.8.3
#     conda-build version : 3.18.9
#          python version : 3.7.4.final.0
#        virtual packages : __glibc=2.27
#        base environment : /usr/local  (writable)
#            channel URLs : https://conda.anaconda.org/conda-forge/linux-64
#                           https://conda.anaconda.org/conda-forge/noarch
#                           https://conda.anaconda.org/bioconda/linux-64
#                           https://conda.anaconda.org/bioconda/noarch
#                           https://repo.anaconda.com/pkgs/main/linux-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/linux-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#           package cache : /usr/local/pkgs
#                           /root/.conda/pkgs
# ...

# %% [markdown]
# Software Packages installation and environment setup complete.

# %% [markdown]
# *
# *
# *
# *
# *
# *

# %% [markdown]
# 1) Install Reference genome and reads for alignment tutorial.

# %%
# !git clone https://github.com/Mangul-Lab-USC/RNA-SEQ-Tutorial-PART1.git

# %% [markdown]
# 2) Perform alignment to reference genome using hisat2.

# %% [markdown]
# 3) Convert sam files to bam files and generate bam index for downstream bioinformatics pipeline.

# %% [markdown]
# 4) Run Htseq-count on the bam files to obtain gene transcripts.

# %% [markdown]
# 5) Run Deseq2 on the gene transcript data to extract differential gene expression analysis.

# %% [markdown]
# 6) Visualize Results of Deseq2.

# %%
import pandas as pd
